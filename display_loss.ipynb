# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from neural_network import load_dataset, train_network

x_train, y_train_hot = load_dataset()
# Out:
# Loading dataset...
# Reshaping dataset...

# %%
losses = train_network(x_train, y_train_hot)
plt.plot(losses)
# Out:
# Creating network...
# Training network...
# Training 1000 of 60000 done.
# Training 2000 of 60000 done.
# Training 3000 of 60000 done.
# Training 4000 of 60000 done.
# Training 5000 of 60000 done.
# Training 6000 of 60000 done.
# Training 7000 of 60000 done.
# Training 8000 of 60000 done.
# Training 9000 of 60000 done.
# Training 10000 of 60000 done.
# Training 11000 of 60000 done.
# Training 12000 of 60000 done.
# Training 13000 of 60000 done.
# Training 14000 of 60000 done.
# Training 15000 of 60000 done.
# Training 16000 of 60000 done.
# Training 17000 of 60000 done.
# Training 18000 of 60000 done.
# Training 19000 of 60000 done.
# Training 20000 of 60000 done.
# Training 21000 of 60000 done.
# Training 22000 of 60000 done.
# Training 23000 of 60000 done.
# Training 24000 of 60000 done.
# Training 25000 of 60000 done.
# Training 26000 of 60000 done.
# Training 27000 of 60000 done.
# Training 28000 of 60000 done.
# Training 29000 of 60000 done.
# Training 30000 of 60000 done.
# Training 31000 of 60000 done.
# Training 32000 of 60000 done.
# Training 33000 of 60000 done.
# Training 34000 of 60000 done.
# Training 35000 of 60000 done.
# Training 36000 of 60000 done.
# Training 37000 of 60000 done.
# Training 38000 of 60000 done.
# Training 39000 of 60000 done.
# Training 40000 of 60000 done.
# Training 41000 of 60000 done.
# Training 42000 of 60000 done.
# Training 43000 of 60000 done.
# Training 44000 of 60000 done.
# Training 45000 of 60000 done.
# Training 46000 of 60000 done.
# Training 47000 of 60000 done.
# Training 48000 of 60000 done.
# Training 49000 of 60000 done.
# Training 50000 of 60000 done.
# Training 51000 of 60000 done.
# Training 52000 of 60000 done.
# Training 53000 of 60000 done.
# Training 54000 of 60000 done.
# Training 55000 of 60000 done.
# Training 56000 of 60000 done.
# Training 57000 of 60000 done.
# Training 58000 of 60000 done.
# Training 59000 of 60000 done.
# End
